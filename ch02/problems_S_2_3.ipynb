# %% [markdown]
# # Principles of Modern Chemistry - 8th Ed. - Oxtoby

# %% [markdown]
# <img src="..//pics/cover_ch.jpg" width=400>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import setuptools

print("setuptools version:", setuptools.__version__)  # Should be < 70.0.0

import vpython as vp
from astropy import units as u
from astropy import constants as const
import sympy as sp
import numpy as np
from IPython.display import display, Math
import matplotlib.pyplot as plt
import sys
from pathlib import Path
from mendeleev import element

print("All imports succeeded!")
# Out:
# setuptools version: 69.5.1
# <div id="glowscript" class="glowscript"></div>
# All imports succeeded!

# %%
# Add root folder to sys.path
sys.path.append(str(Path("..").resolve()))

# Import your helper function directly
from helper_functions import fmt_vec, balance_reaction

# %%
# !python --version
# Out:
# Python 3.12.10

# %%
pwd
# Out:
# 'c:\\Users\\crodr\\BK_tech\\Chemistry\\BK_Principles_MQ_Oxtoby_8\\ch02'

# %% [markdown]
# # 2 Chemical Formulas, Equations, and Reaction Yields
# ## PROBLEMS
# ### 2.3 Writing Balanced Chemical Equations
# #### 19
#
# page 49b
#
# Balance the following chemical equations:
#
# **(a)**
#
# $$H_2 + N_2 \implies NH_3$$

# %%
# Add root folder to sys.path
sys.path.append(str(Path("..").resolve()))

# Import your helper function directly
from helper_functions import balance_reaction


reactants = ["H2", "N2"]
products = ["NH3"]

balanced_eq = balance_reaction(reactants, products)

print(f"Unbalanced : {' + '.join(reactants)} -> {' + '.join(products)}")
print(f"Balanced   : {balanced_eq}")
# Out:
# Unbalanced : H2 + N2 -> NH3
# Balanced   : 3H2 + N2 ==> 2NH3

# %% [markdown]
# **(b)**
#
# $$K + O_2 \implies K_2O_2$$

# %%
reactants = ["K", "O2"]
products = ["K2O2"]

balanced_eq = balance_reaction(reactants, products)

print(f"Unbalanced : {' + '.join(reactants)} -> {' + '.join(products)}")
print(f"Balanced   : {balanced_eq}")
# Out:
# Unbalanced : K + O2 -> K2O2
# Balanced   : 2K + O2 ==> K2O2

# %% [markdown]
# **(c)**
#
# $$PbO_2 + Pb + H_2SO_4 \implies PbSO_4 + H_2O$$

# %%
reactants = ["PbO2", "Pb", "H2SO4"]
products = ["PbSO4", "H2O"]

balanced_eq = balance_reaction(reactants, products)

print(f"Unbalanced : {' + '.join(reactants)} -> {' + '.join(products)}")
print(f"Balanced   : {balanced_eq}")
# Out:
# Unbalanced : PbO2 + Pb + H2SO4 -> PbSO4 + H2O
# Balanced   : PbO2 + Pb + 2H2SO4 ==> 2PbSO4 + 2H2O

# %% [markdown]
# **(d)**
#
# $$ BF_3 + H_2O  \implies B_2O_3 + HF$$

# %%
reactants = ["BF3", "H2O"]
products = ["B2O3", "HF"]

balanced_eq = balance_reaction(reactants, products)

print(f"Unbalanced : {' + '.join(reactants)} -> {' + '.join(products)}")
print(f"Balanced   : {balanced_eq}")
# Out:
# Unbalanced : BF3 + H2O -> B2O3 + HF
# Balanced   : 2BF3 + 3H2O ==> B2O3 + 6HF

# %% [markdown]
# **(e)**
#
# $$KClO_3 \implies KCl + O_2$$

# %%
reactants = ["KClO3"]
products = ["KCl", "O2"]

balanced_eq = balance_reaction(reactants, products)

print(f"Unbalanced : {' + '.join(reactants)} -> {' + '.join(products)}")
print(f"Balanced   : {balanced_eq}")
# Out:
# Unbalanced : KClO3 -> KCl + O2
# Balanced   : 2KClO3 ==> 2KCl + 3O2

# %% [markdown]
# **(f)**
#
# $$CH_3COOH + O_2 \implies CO_2 + H_2O$$

# %%
reactants = ["CH3COOH", "O2"]
products = ["CO2", "H2O"]

balanced_eq = balance_reaction(reactants, products)

print(f"Unbalanced : {' + '.join(reactants)} -> {' + '.join(products)}")
print(f"Balanced   : {balanced_eq}")
# Out:
# Unbalanced : CH3COOH + O2 -> CO2 + H2O
# Balanced   : CH3COOH + 2O2 ==> 2CO2 + 2H2O

# %% [markdown]
# **(g)**
#
# $$K_2O_2  + H_2O \implies KOH + O_2$$

# %%
reactants = ["K2O2", "H2O"]
products = ["KOH", "O2"]

balanced_eq = balance_reaction(reactants, products)

print(f"Unbalanced : {' + '.join(reactants)} -> {' + '.join(products)}")
print(f"Balanced   : {balanced_eq}")
# Out:
# Unbalanced : K2O2 + H2O -> KOH + O2
# Balanced   : 2K2O2 + 2H2O ==> 4KOH + O2

# %% [markdown]
# **(h)**
#
# $$PCl_5 + AsF_3 \implies PF_5 + AsCl_3$$

# %%
reactants = ["PCl5", "AsF3"]
products = ["PF5", "AsCl3"]

balanced_eq = balance_reaction(reactants, products)

print(f"Unbalanced : {' + '.join(reactants)} -> {' + '.join(products)}")
print(f"Balanced   : {balanced_eq}")
# Out:
# Unbalanced : PCl5 + AsF3 -> PF5 + AsCl3
# Balanced   : 3PCl5 + 5AsF3 ==> 3PF5 + 5AsCl3

# %% [markdown]
# #### 20
#
# page 49b
#
# Balance the following chemical equations:
#
# **(a)**
#
# $$ Al + HCl \implies AlCl_3 + H_2$$

# %%
reactants = ["Al", "HCl"]
products = ["AlCl3", "H2"]

balanced_eq = balance_reaction(reactants, products)

print(f"Unbalanced : {' + '.join(reactants)} -> {' + '.join(products)}")
print(f"Balanced   : {balanced_eq}")
# Out:
# Unbalanced : Al + HCl -> AlCl3 + H2
# Balanced   : 2Al + 6HCl ==> 2AlCl3 + 3H2

# %% [markdown]
# **(b)**
#
# $$NH_3 + O_2 \implies NO + H_2O$$

# %%
reactants = ["NH3", "O2"]
products = ["NO", "H2O"]

balanced_eq = balance_reaction(reactants, products)

print(f"Unbalanced : {' + '.join(reactants)} -> {' + '.join(products)}")
print(f"Balanced   : {balanced_eq}")
# Out:
# Unbalanced : NH3 + O2 -> NO + H2O
# Balanced   : 4NH3 + 5O2 ==> 4NO + 6H2O

# %% [markdown]
# **(c)**
#
# $$Fe + O_2 + H_2O \implies Fe(OH)_2$$

# %%
reactants = ["Fe", "O2", "H2O"]
products = ["FeO2H2"]

balanced_eq = balance_reaction(reactants, products)

print(f"Unbalanced : {' + '.join(reactants)} -> {' + '.join(products)}")
print(f"Balanced   : {balanced_eq}")
# Out:
# Unbalanced : Fe + O2 + H2O -> FeO2H2
# Balanced   : 2Fe + O2 + 2H2O ==> 2FeO2H2

# %% [markdown]
# **(d)**
#
# $$HSbCl_4 + H_2S \implies Sb_2S_3 + HCl$$

# %%
reactants = ["HSbCl4", "H2S"]
products = ["Sb2S3", "HCl"]

balanced_eq = balance_reaction(reactants, products)

print(f"Unbalanced : {' + '.join(reactants)} -> {' + '.join(products)}")
print(f"Balanced   : {balanced_eq}")
# Out:
# Unbalanced : HSbCl4 + H2S -> Sb2S3 + HCl
# Balanced   : 2HSbCl4 + 3H2S ==> Sb2S3 + 8HCl

# %% [markdown]
# **(e)**
#
# $$ Al + Cr_2O_3 \implies Al_2O_3 + Cr$$

# %%
reactants = ["Al", "Cr2O3"]
products = ["Al2O3", "Cr"]

balanced_eq = balance_reaction(reactants, products)

print(f"Unbalanced : {' + '.join(reactants)} -> {' + '.join(products)}")
print(f"Balanced   : {balanced_eq}")
# Out:
# Unbalanced : Al + Cr2O3 -> Al2O3 + Cr
# Balanced   : 2Al + Cr2O3 ==> Al2O3 + 2Cr

# %% [markdown]
# **(f)**
#
# $$XeF_4 + H_2O \implies Xe + O_2 + HF$$

# %%
reactants = ["XeF4", "H2O"]
products = ["Xe", "O2", "HF"]

balanced_eq = balance_reaction(reactants, products)

print(f"Unbalanced : {' + '.join(reactants)} -> {' + '.join(products)}")
print(f"Balanced   : {balanced_eq}")
# Out:
# Unbalanced : XeF4 + H2O -> Xe + O2 + HF
# Balanced   : XeF4 + 2H2O ==> Xe + O2 + 4HF

# %% [markdown]
# **(g)**
#
# $$(NH_4)_2Cr_2O_7 \implies N_2 + Cr_2O_3 + H_2O$$

# %%
reactants = ["N2H8Cr2O7"]
products = ["N2", "Cr2O3", "H2O"]

balanced_eq = balance_reaction(reactants, products)

print(f"Unbalanced : {' + '.join(reactants)} -> {' + '.join(products)}")
print(f"Balanced   : {balanced_eq}")
# Out:
# Unbalanced : N2H8Cr2O7 -> N2 + Cr2O3 + H2O
# Balanced   : N2H8Cr2O7 ==> N2 + Cr2O3 + 4H2O

# %% [markdown]
# **(h)**
#
# $$NaBH_4 + H_2O \implies NaBO_2 + H_2$$

# %%
reactants = ["NaBH4", "H2O"]
products = ["NaBO2", "H2"]

balanced_eq = balance_reaction(reactants, products)

print(f"Unbalanced : {' + '.join(reactants)} -> {' + '.join(products)}")
print(f"Balanced   : {balanced_eq}")
# Out:
# Unbalanced : NaBH4 + H2O -> NaBO2 + H2
# Balanced   : NaBH4 + 2H2O ==> NaBO2 + 4H2
