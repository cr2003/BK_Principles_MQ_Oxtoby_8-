# %% [markdown]
# # Principles of Modern Chemistry - 8th Ed. - Oxtoby

# %% [markdown]
# <img src="..//pics/cover_ch.jpg" width=400>

# %%
import setuptools

print("setuptools version:", setuptools.__version__)  # Should be < 70.0.0

import vpython as vp
from astropy import units as u
from astropy import constants as const
import sympy as sp
import numpy as np
from IPython.display import display, Math
import matplotlib.pyplot as plt
import sys
from pathlib import Path

print("All imports succeeded!")
# Out:
# setuptools version: 69.5.1
# <div id="glowscript" class="glowscript"></div>
# All imports succeeded!

# %%
# Add root folder to sys.path
sys.path.append(str(Path("..").resolve()))

# Import your helper function directly
from helper_functions import fmt_vec

# %%
# !python --version
# Out:
# Python 3.12.10

# %%
pwd
# Out:
# 'c:\\Users\\crodr\\BK_tech\\Chemistry\\BK_Principles_MQ_Oxtoby_8\\Appendix'

# %% [markdown]
# # Appendix
# # A Scientific Notation and Experimental Error
# ## Problems
# ### A.2 E xperimental Error
#
# page 1161
#
# #### 7
#
# A group of students took turns using a laboratory balance
# to weigh the water contained in a beaker. The results they
# reported were 111.42 g, 111.67 g, 111.21 g, 135.64 g,
# 111.02 g, 111.29 g, and 111.42 g.
#
# **(a)** Should any of the data be excluded before the average
# is calculated?

# %%
# Dataset with units
raw_data = [111.42, 111.67, 111.21, 135.64, 111.02, 111.29, 111.42] * u.g

# (a) Filter outlier (> 120 g)
clean_data = raw_data[raw_data < 120 * u.g]
print(f"Excluded outlier: 135.64 g")
# Out:
# Excluded outlier: 135.64 g

# %% [markdown]
# **(b)** From the remaining measurements,
# calculate the average
# value of the mass of the water in the beaker.

# %%
# (b) Average value
mean_mass = np.mean(clean_data)
print(f"Average mass: {mean_mass:.2f}")
# Out:
# Average mass: 111.34 g

# %% [markdown]
# **(c)** Calculate the standard deviation $\sigma$ and, from it, the
# 95% confidence limit.

# %%
# (c) Standard deviation & 95% confidence limit
std_dev = np.std(clean_data, ddof=1)  # Sample standard deviation
n = len(clean_data)
t = 2.57  # taken from the table for N=6 and and 95%
margin_of_error = (t * std_dev) / np.sqrt(n)
print(f"Margin of Error: ±{margin_of_error:.2f}")
# Out:
# Margin of Error: ±0.23 g

# %% [markdown]
# #### 8
#
# By measuring the sides of a small box, a group of students
# made the following estimates for its volume: 544 cm3, 590
# cm3, 523 cm3, 560 cm3, 519 cm3, 570 cm3, and 578 cm3.
#
# **(a)** Should any of the data be excluded before the average
# is calculated?

# %%
# Dataset with units

raw_data = [544, 590, 523, 560, 519, 570, 578] * u.cm**3

# (a) Filter outlier (> 580 g)
clean_data = raw_data[raw_data < 580 * u.cm**3]
print(f"Excluded outlier: 590 cm**3")
# Out:
# Excluded outlier: 590 cm**3

# %% [markdown]
# **(b)** Calculate the average value of the volume of the box
# from the remaining measurements.

# %%
# (b) Average value
mean_volume = np.mean(clean_data)
print(f"Average volume: {mean_volume:.0f}")
# Out:
# Average volume: 549 cm3

# %% [markdown]
# (c) Calculate the standard deviation s and, from it, the
# 90% confidence limit.

# %%
# (c) Standard deviation & 90% confidence limit
std_dev = np.std(clean_data, ddof=1)  # Sample standard deviation
n = len(clean_data)
t = 1.94  # taken from the table for N=7 and and 90%
margin_of_error = (t * std_dev) / np.sqrt(n)
print(f"Margin of Error: ±{margin_of_error:.0f}")
# Out:
# Margin of Error: ±19 cm3

# %% [markdown]
# #### 9. Of the measurements
# in problems 7 and 8, which is more
# precise?

# %%
print(f"More precise mass in problem 7.")
# Out:
# More precise mass in problem 7.
